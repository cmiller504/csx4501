# %% [markdown]
# # Assignment 04 - EDA on World Happiness Report (2015-2022)
#
# **Background**
#
# The World Happiness Report is a landmark survey of the state of global happiness. It was first published in 2012, each year after, and updated in 2016. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# **Data summary**
#
# This file contains the Happiness Score for about 150 countries along with the factors used to explain the score. The Happiness Score is a national average of the responses to the main life evaluation question asked in the Gallup World Poll (GWP), which uses the Cantril Ladder.
#
# The Happiness Score is explained by the following factors:
#
# GDP per capita
#
# Healthy Life Expectancy
#
# Social support
#
# Freedom to make life choices
#
# Generosity
#
# Corruption Perception
#
# Residual error
#
# **More detail**
#
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# * What is Dystopia?
#
#    Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# * What are the residuals?
#
#    The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average 2014-2016 life evaluations. These residuals have an average value of approximately zero over the whole set of countries. Figure 2.2 shows the average residual for each country when the equation in Table 2.1 is applied to average 2014- 2016 data for the six variables in that country. We combine these residuals with the estimate for life evaluations in Dystopia so that the combined bar will always have positive values. As can be seen in Figure 2.2, although some life evaluation residuals are quite large, occasionally exceeding one point on the scale from 0 to 10, they are always much smaller than the calculated value in Dystopia, where the average life is rated at 1.85 on the 0 to 10 scale.
#
# * What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?
#
#    The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country as stated in the previous answer.
#
# **_If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores_**
#
# source: [data retrieved from kaggle](https://www.kaggle.com/datasets/mathurinache/world-happiness-report)

# %% [markdown]
# **Importing 2022 dataset to check it out...**

# %%
import pandas as pd
dat2022 = pd.read_csv("WorldHappinessReport2015-2022/2022.csv")

dat2022
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 0       1      Finland           7,821        7,886       7,756
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
# 146   147           xx             NaN          NaN         NaN
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# 1                        2,226                        1,953
# ...

# %% [markdown]
# **looks like there are commas when there should be decimal points so let's try...**

# %%
dat2022 = pd.read_csv("WorldHappinessReport2015-2022/2022.csv",decimal=',')

dat2022
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 142   143      Rwanda*            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
# 146   147           xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %% [markdown]
# **Print the first several rows, the last several rows, and a sample row or two**

# %%
dat2022.head(10)
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
# 5     6  Luxembourg*            7.404         7.501        7.307
# 6     7       Sweden            7.384         7.454        7.315
# 7     8       Norway            7.365         7.440        7.290
# 8     9       Israel            7.364         7.426        7.301
# 9    10  New Zealand            7.200         7.279        7.120
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# ...

# %%
dat2022.tail(10)
# Out:
#      RANK       Country  Happiness score  Whisker-high  Whisker-low  \
# 137   138        Malawi            3.750         3.941        3.560
# 138   139      Tanzania            3.702         3.847        3.558
# 139   140  Sierra Leone            3.574         3.732        3.416
# 140   141      Lesotho*            3.512         3.748        3.276
# 141   142     Botswana*            3.471         3.667        3.275
# 142   143       Rwanda*            3.268         3.462        3.074
# 143   144      Zimbabwe            2.995         3.110        2.880
# 144   145       Lebanon            2.955         3.049        2.862
# 145   146   Afghanistan            2.404         2.469        2.339
# 146   147            xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 137                       1.661                         0.648
# 138                       0.735                         0.848
# ...

# %%
dat2022[56:58]
# Out:
#     RANK    Country  Happiness score  Whisker-high  Whisker-low  \
# 56    57  Argentina            5.967         6.090        5.844
# 57    58     Greece            5.948         6.043        5.853
#
#     Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 56                       1.891                         1.592
# 57                       2.119                         1.703
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 56                         1.102                                  0.662
# 57                         0.980                                  0.774
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 56                                       0.555                     0.081
# 57                                       0.249                     0.015
#
#     Explained by: Perceptions of corruption
# 56                                    0.085
# 57                                    0.108

# %% [markdown]
# **Check what features are included, and check that sample values of each feature have reasonable values**

# %%
dat2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %%
dat2022.describe(include = 'all')
# Out:
#               RANK Country  Happiness score  Whisker-high  Whisker-low  \
# count   147.000000     147       146.000000    146.000000   146.000000
# unique         NaN     147              NaN           NaN          NaN
# top            NaN    Iran              NaN           NaN          NaN
# freq           NaN       1              NaN           NaN          NaN
# mean     74.000000     NaN         5.553575      5.673589     5.433568
# std      42.579338     NaN         1.086843      1.065621     1.109380
# min       1.000000     NaN         2.404000      2.469000     2.339000
# 25%      37.500000     NaN         4.888750      5.006250     4.754750
# 50%      74.000000     NaN         5.568500      5.680000     5.453000
# 75%     110.500000     NaN         6.305000      6.448750     6.190000
# max     147.000000     NaN         7.821000      7.886000     7.756000
#
#         Dystopia (1.83) + residual  Explained by: GDP per capita  \
# ...

# %% [markdown]
# **It looks like...**
# * **rank goes from 1 to 147, so should be one for each country?**
# * **happiness is on a scale from 1-10? min is 2.4, max is 7.8**
# * **other values are on a scale from 0-1**
# * **maybe one row is missing all values? 146 non-null count for all variables except rank and country, but let's check**

# %% [markdown]
# **Check if there are any null values (NaNs)**

# %%
dat2022.isna().sum().sum()
# Out:
# 10

# %% [markdown]
# **Which row has NaNs?**

# %%
nan_rows = dat2022[dat2022.isna().any(axis=1)]

nan_rows
# Out:
#      RANK Country  Happiness score  Whisker-high  Whisker-low  \
# 146   147      xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 146                         NaN                           NaN
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 146                           NaN                                    NaN
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 146                                         NaN                       NaN
#
#      Explained by: Perceptions of corruption
# 146                                      NaN

# %% [markdown]
# **let's ditch that row and see how the data looks...**

# %%
dat2022_noNAN = dat2022[0:145]

dat2022_noNAN.isna().sum().sum()
# Out:
# 0

# %%
dat2022_noNAN.describe()
# Out:
#              RANK  Happiness score  Whisker-high  Whisker-low  \
# count  145.000000       145.000000    145.000000   145.000000
# mean    73.000000         5.575297      5.695690     5.454910
# std     42.001984         1.058332      1.035194     1.082732
# min      1.000000         2.955000      3.049000     2.862000
# 25%     37.000000         4.891000      5.028000     4.760000
# 50%     73.000000         5.578000      5.681000     5.467000
# 75%    109.000000         6.309000      6.460000     6.202000
# max    145.000000         7.821000      7.886000     7.756000
#
#        Dystopia (1.83) + residual  Explained by: GDP per capita  \
# count                  145.000000                    145.000000
# mean                     1.835731                      1.414945
# std                      0.534737                      0.419593
# min                      0.187000                      0.000000
# 25%                      1.556000                      1.100000
# ...

# %%
dat2022_noNAN.tail() # (just proving to myself that the row is gone)
# Out:
#      RANK    Country  Happiness score  Whisker-high  Whisker-low  \
# 140   141   Lesotho*            3.512         3.748        3.276
# 141   142  Botswana*            3.471         3.667        3.275
# 142   143    Rwanda*            3.268         3.462        3.074
# 143   144   Zimbabwe            2.995         3.110        2.880
# 144   145    Lebanon            2.955         3.049        2.862
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 140                       1.312                         0.839
# 141                       0.187                         1.503
# 142                       0.536                         0.785
# 143                       0.548                         0.947
# 144                       0.216                         1.392
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 140                         0.848                                  0.000
# ...

# %% [markdown]
# **Check that data types are appropriate, and change any that are not**

# %%
dat2022_noNAN.dtypes
# Out:
# RANK                                            int64
# Country                                        object
# Happiness score                               float64
# Whisker-high                                  float64
# Whisker-low                                   float64
# Dystopia (1.83) + residual                    float64
# Explained by: GDP per capita                  float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# dtype: object

# %% [markdown]
# **looks right, country is a string(object), and all of the other numbers have decimals so they are floats**

# %% [markdown]
# **For each feature, make a plot that shows the variability in its values (rank is self explanatory, but let's look at the explanatory variables**

# %%
dat2022_noNAN.plot(x = "Country", y= "Happiness score", kind = "scatter");
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness score'>

# %%
dat2022_noNAN.plot(x = "Country", y= "Explained by: GDP per capita", kind = "scatter");
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Explained by: GDP per capita'>

# %%
dat2022_noNAN.plot(x = "Country", y= "Explained by: Social support", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Country", y= "Explained by: Healthy life expectancy", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Country", y= "Explained by: Freedom to make life choices", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Country", y= "Explained by: Generosity", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Country", y= "Explained by: Perceptions of corruption", kind = "scatter");

# %% [markdown]
# **Choose several pairs of features, and make plots showing how their values vary relative to each other**

# %%
dat2022_noNAN.plot(x = "Explained by: Healthy life expectancy", y= "Explained by: Social support", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Explained by: Healthy life expectancy", y= "Explained by: Freedom to make life choices", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Explained by: Healthy life expectancy", y= "Explained by: Generosity", kind = "scatter");

# %%
dat2022_noNAN.plot(x = "Explained by: Perceptions of corruption", y= "Explained by: GDP per capita", kind = "scatter");

# %% [markdown]
# **Is any further data pre-processing needed?**
#
# I think the only thing that needed to be done was removing the NANs
# However, when combining the other datasets (2015 - 2021), it is likely that some columnns, etc will not match up completely
#
# **Three questions worth further investigation?**
#
# * How has happiness changed since COVID (2020)?
# * Which countries have most variablity in happiness over time?
# * Since we can't use the variables to predict happiness scores (because they composite them), I'm wondering what other factors (from other country level data sources) may relate to happiness. For example, does environment (e.g. access to nature, percent urban, etc.) correate with happiness?
